# %%
import joblib
import pandas as pd

model = joblib.load("model.pkl")

test_data = pd.DataFrame([{
    "age": 45,
    "sex": 1,
    "cp": 2,
    "trestbps": 130,
    "chol": 250,
    "fbs": 0,
    "restecg": 1,
    "thalach": 160,
    "exang": 0,
    "oldpeak": 1.2,
    "slope": 1,
    "ca": 0
   
}])

pred = model.predict(test_data)
print("Prediction:", pred)
# Out:
# Prediction: [1]
